# %%
import os
import sys
import inspect
# Insert modules directory, TODO create setup.py file
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
reports_dir = os.path.dirname(currentdir)
project_home_dir = os.path.dirname(reports_dir)
sys.path.insert(0, f"{project_home_dir}/qcnn")

# %%
import numpy as np
import pandas as pd
from pprint import  pprint
from reporting_functions import get_file_content, get_multiclass_results
from joblib import dump, load

# %%
experiments_path = f"{project_home_dir}/experiments"
experiment_filename = "experiment.json"
target_levels = ["classical", "country", "rock", "pop", "hiphop", "jazz", "blues", "disco", "metal", "reggae"]

# %%
experiment_id = 108
experiment_config = get_file_content(
    f"{experiments_path}/{experiment_id}/{experiment_filename}"
)

# %%
pprint(experiment_config)
# Out:
# {'ID': 108,
#  'data': {'path': '/home/matt/dev/projects/quantum-cnn/data/archive/Data/features_30_sec.csv',
#           'sampling': {'random_state': 42, 'test_size': 0.3},
#           'target_column': 'label',
#           'target_pairs': [['classical', 'country'],
#                            ['classical', 'rock'],
#                            ['classical', 'pop'],
#                            ['classical', 'hiphop'],
#                            ['classical', 'jazz'],
#                            ['classical', 'blues'],
#                            ['classical', 'disco'],
#                            ['classical', 'metal'],
#                            ['classical', 'reggae'],
#                            ['country', 'rock'],
#                            ['country', 'pop'],
#                            ['country', 'hiphop'],
#                            ['country', 'jazz'],
#                            ['country', 'blues'],
#                            ['country', 'disco'],
#                            ['country', 'metal'],
#                            ['country', 'reggae'],
#                            ['rock', 'pop'],
#                            ['rock', 'hiphop'],
#                            ['rock', 'jazz'],
#                            ['rock', 'blues'],
#                            ['rock', 'disco'],
#                            ['rock', 'metal'],
#                            ['rock', 'reggae'],
#                            ['pop', 'hiphop'],
#                            ['pop', 'jazz'],
#                            ['pop', 'blues'],
#                            ['pop', 'disco'],
#                            ['pop', 'metal'],
#                            ['pop', 'reggae'],
#                            ['hiphop', 'jazz'],
#                            ['hiphop', 'blues'],
#                            ['hiphop', 'disco'],
#                            ['hiphop', 'metal'],
#                            ['hiphop', 'reggae'],
#                            ['jazz', 'blues'],
#                            ['jazz', 'disco'],
#                            ['jazz', 'metal'],
#                            ['jazz', 'reggae'],
#                            ['blues', 'disco'],
#                            ['blues', 'metal'],
#                            ['blues', 'reggae'],
#                            ['disco', 'metal'],
#                            ['disco', 'reggae'],
#                            ['metal', 'reggae']],
#           'type': '2d'},
#  'extra_info': 'main',
#  'model': {'classical': {'cnn': {'ignore': True, 'param_grid': {}},
#                          'logistic_regression': {'ignore': False,
#                                                  'param_grid': {'C': [0.001,
#                                                                       0.01,
#                                                                       0.1,
#                                                                       1.0,
#                                                                       10.0,
#                                                                       100.0,
#                                                                       1000.0],
#                                                                 'penalty': ['l1',
#                                                                             'l2']}},
#                          'svm': {'ignore': False,
#                                  'param_grid': {'C': [1, 10, 100],
#                                                 'kernel': ['linear',
#                                                            'rbf',
#                                                            'poly',
#                                                            'sigmoid']}}},
#            'classification_type': 'binary',
#            'quantum': {'qcnn': {'circuit_list': ['U_5', 'U_SU4'],
#                                 'custom_structures': {'custom_0': {'c_1': [0,
#                                                                            'c_1',
#                                                                            'U_5'],
#                                                                    'c_2': [2,
#                                                                            'c_2',
#                                                                            'U_SU4'],
#                                                                    'c_3': [4,
#                                                                            'c_3',
#                                                                            'U_6'],
#                                                                    'p_1': [1,
#                                                                            'p_1',
#                                                                            'psatz1'],
#                                                                    'p_2': [3,
#                                                                            'p_2',
#                                                                            'psatz1'],
#                                                                    'p_3': [5,
#                                                                            'p_3',
#                                                                            'psatz1']},
#                                                       'custom_1': {'c_1': [0,
#                                                                            'c_1',
#                                                                            'U_5'],
#                                                                    'c_2': [2,
#                                                                            'c_2',
#                                                                            'U_SU4'],
#                                                                    'c_3': [4,
#                                                                            'c_3',
#                                                                            'U_5'],
#                                                                    'p_1': [1,
#                                                                            'p_1',
#                                                                            'psatz1'],
#                                                                    'p_2': [3,
#                                                                            'p_2',
#                                                                            'psatz1'],
#                                                                    'p_3': [5,
#                                                                            'p_3',
#                                                                            'psatz1']}},
#                                 'ignore': True,
#                                 'pooling_list': ['psatz1']}}},
#  'path': '/home/matt/dev/projects/quantum-cnn/experiments',
#  'preprocessing': {'classical': {'normal': {'feature_selection': {'method': {'pca': {'n_components': [8]},
#                                                                              'tree': {'max_features': [8],
#                                                                                       'n_estimators': [50]}}},
#                                             'ignore': False,
#                                             'scaler': {'method': {'minmax': {'feature_range': [[0,
#                                                                                                 1],
#                                                                                                [-1,
#                                                                                                 1],
#                                                                                                [0,
#                                                                                                 1.5707963267948966]]},
#                                                                   'standard': {}}}},
#                                  'other': {'feature_selection': {'method': {'identity': {}}},
#                                            'ignore': True,
#                                            'scaler': {'method': {'identity': {}}}}},
#                    'quantum': {'Amplitude': {'feature_selection': {'method': {'pca': {'n_components': [8]},
#                                                                               'tree': {'max_features': [8],
#                                                                                        'n_estimators': [50]}}},
#                                              'ignore': True,
#                                              'scaler': {'method': {'minmax': {'feature_range': [[0,
#                                                                                                  1],
#                                                                                                 [-1,
#                                                                                                  1],
#                                                                                                 [0,
#                                                                                                  1.5707963267948966]]},
#                                                                    'standar': {}}}},
#                                'Angle': {'feature_selection': {'method': {'pca': {'n_components': [8]},
#                                                                           'tree': {'max_features': [8],
#                                                                                    'n_estimators': [50]}}},
#                                          'ignore': True,
#                                          'scaler': {'method': {'minmax': {'feature_range': [[0,
#                                                                                              1],
#                                                                                             [-1,
#                                                                                              1],
#                                                                                             [0,
#                                                                                              1.5707963267948966]]},
#                                                                'standar': {}}}},
#                                'IQP': {'feature_selection': {'method': {'pca': {'n_components': [8]},
#                                                                         'tree': {'max_features': [8],
#                                                                                  'n_estimators': [50]}}},
#                                        'ignore': True,
#                                        'kwargs': {'depth': 10},
#                                        'scaler': {'method': {'minmax': {'feature_range': [[0,
#                                                                                            1],
#                                                                                           [-1,
#                                                                                            1],
#                                                                                           [0,
#                                                                                            1.5707963267948966]]},
#                                                              'standar': {}}}}}},
#  'train': {'iterations': 40}}

# %%
path = f"{experiment_config.get('path')}/{experiment_config.get('ID')}"

# %%
y_test = pd.read_csv(f"{path}/y_test.csv", index_col=0)

# %%
model_names = [filename.split("-confusion-matrix.csv")[0] for filename in os.listdir(path) if "-confusion-matrix.csv" in filename]

# %%
for model_name in model_names:
    y_hat = pd.read_csv(f"{path}/{model_name}-yhat.csv", index_col=0)
    clf = load(f"{path}/{model_name}-clf-grid-results.joblib")
    est = load(f"{path}/{model_name}-estimator.joblib")
    dsp, display_report = get_multiclass_results(y_test, y_hat, model_name=model_name)
    # print(model_name)
    # print(display_report)
    # means = clf.cv_results_["mean_test_score"]
    # stds = clf.cv_results_["std_test_score"]
    # for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
    #     print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-d7af0acfc3b2> in <module>
#       3     clf = load(f"{path}/{model_name}-clf-grid-results.joblib")
#       4     est = load(f"{path}/{model_name}-estimator.joblib")
# ----> 5     dsp, display_report = get_multiclass_results(y_test, y_hat, model_name=model_name)
#       6     # print(model_name)
#       7     # print(display_report)
#
# ~/dev/projects/quantum-cnn/qcnn/reporting_functions.py in get_multiclass_results(y_test, y_class_multi, target_levels, model_name)
#     489 def get_multiclass_results(y_test, y_class_multi, target_levels=None, model_name=None):
#     490
# --> 491     display_report = classification_report(y_test, y_class_multi)
#     492     confusion = confusion_matrix(y_test, y_class_multi, labels=target_levels)
#     493
#
# ~/dev/projects/quantum-cnn/python_env/qcnn/lib/python3.9/site-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2074     """
#    2075
# -> 2076     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2077
#    2078     if labels is None:
#
# ~/dev/projects/quantum-cnn/python_env/qcnn/lib/python3.9/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# ~/dev/projects/quantum-cnn/python_env/qcnn/lib/python3.9/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     329     uniques = np.unique(lengths)
#     330     if len(uniques) > 1:
# --> 331         raise ValueError(
#     332             "Found input variables with inconsistent numbers of samples: %r"
#     333             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [300, 71]

# %%
y_hat
# Out:
#     0
# 0   0
# 1   1
# 2   1
# 3   0
# 4   0
# .. ..
# 66  0
# 67  1
# 68  1
# 69  0
# 70  1
#
# [71 rows x 1 columns]
